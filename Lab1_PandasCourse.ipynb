# %% [markdown]
# ## Question 1

# %%
import requests

url = "https://community-open-weather-map.p.rapidapi.com/climate/month"

querystring = {"q":"Cairo"}

headers = {
    'x-rapidapi-host': "community-open-weather-map.p.rapidapi.com",
    'x-rapidapi-key': "48cb9bda44msh0c02bce516cb3bbp116596jsn4b6b1a06dc81"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"cod":"200","city":{"id":360630,"name":"Cairo","coord":{"lon":31.2497,"lat":30.0626},"country":"EG"},"message":0.346127777,"list":[{"dt":1642204800,"humidity":63.12,"pressure":1019.07,"temp":{"average":286.83,"average_max":291.16,"average_min":282.85,"record_max":294.12,"record_min":276.99},"wind_speed":4.55},{"dt":1642291200,"humidity":57.76,"pressure":1017.88,"temp":{"average":286.19,"average_max":291.17,"average_min":281.83,"record_max":295,"record_min":276.32},"wind_speed":4.86},{"dt":1642377600,"humidity":60.96,"pressure":1017.27,"temp":{"average":286.6,"average_max":291.21,"average_min":281.4,"record_max":293.93,"record_min":275.03},"wind_speed":4.08},{"dt":1642464000,"humidity":59.32,"pressure":1018.62,"temp":{"average":286.67,"average_max":290.93,"average_min":281.7,"record_max":295.15,"record_min":274.36},"wind_speed":4.9},{"dt":1642550400,"humidity":63.17,"pressure":1019.84,"temp":{"average":286.26,"average_max":291.04,"average_min":281.27,"record_max":293.95,"record_min":
# ...

# %%
import json
json.loads(response.text)
# Out:
# {'cod': '200',
#  'city': {'id': 360630,
#   'name': 'Cairo',
#   'coord': {'lon': 31.2497, 'lat': 30.0626},
#   'country': 'EG'},
#  'message': 0.346127777,
#  'list': [{'dt': 1642204800,
#    'humidity': 63.12,
#    'pressure': 1019.07,
#    'temp': {'average': 286.83,
#     'average_max': 291.16,
#     'average_min': 282.85,
#     'record_max': 294.12,
#     'record_min': 276.99},
#    'wind_speed': 4.55},
#   {'dt': 1642291200,
#    'humidity': 57.76,
#    'pressure': 1017.88,
#    'temp': {'average': 286.19,
#     'average_max': 291.17,
#     'average_min': 281.83,
#     'record_max': 295,
#     'record_min': 276.32},
#    'wind_speed': 4.86},
#   {'dt': 1642377600,
#    'humidity': 60.96,
#    'pressure': 1017.27,
#    'temp': {'average': 286.6,
#     'average_max': 291.21,
#     'average_min': 281.4,
#     'record_max': 293.93,
#     'record_min': 275.03},
#    'wind_speed': 4.08},
#   {'dt': 1642464000,
#    'humidity': 59.32,
#    'pressure': 1018.62,
# ...

# %%
import pandas as pd
df_from_API = pd.DataFrame(json.loads(response.text)['list'])
df_from_API.head(2)
# Out:
#            dt  humidity  pressure  \
# 0  1642204800     63.12   1019.07
# 1  1642291200     57.76   1017.88
#
#                                                 temp  wind_speed
# 0  {'average': 286.83, 'average_max': 291.16, 'av...        4.55
# 1  {'average': 286.19, 'average_max': 291.17, 'av...        4.86

# %%
df_from_API = pd.concat([df_from_API, pd.json_normalize(df_from_API['temp'])], axis=1)
df_from_API.head(2)
# Out:
#            dt  humidity  pressure  \
# 0  1642204800     63.12   1019.07
# 1  1642291200     57.76   1017.88
#
#                                                 temp  wind_speed  average  \
# 0  {'average': 286.83, 'average_max': 291.16, 'av...        4.55   286.83
# 1  {'average': 286.19, 'average_max': 291.17, 'av...        4.86   286.19
#
#    average_max  average_min  record_max  record_min
# 0       291.16       282.85      294.12      276.99
# 1       291.17       281.83      295.00      276.32

# %%
del df_from_API['temp']
df_from_API
# Out:
#             dt  humidity  pressure  wind_speed  average  average_max  \
# 0   1642204800     63.12   1019.07        4.55   286.83       291.16
# 1   1642291200     57.76   1017.88        4.86   286.19       291.17
# 2   1642377600     60.96   1017.27        4.08   286.60       291.21
# 3   1642464000     59.32   1018.62        4.90   286.67       290.93
# 4   1642550400     63.17   1019.84        4.30   286.26       291.04
# 5   1642636800     58.39   1021.31        3.65   286.25       291.49
# 6   1642723200     54.07   1020.47        3.55   287.23       293.07
# 7   1642809600     53.70   1018.68        3.78   287.90       293.44
# 8   1642896000     55.81   1017.87        3.91   287.70       292.27
# 9   1642982400     56.60   1017.74        3.92   288.09       292.74
# 10  1643068800     57.74   1018.05        3.46   287.92       293.00
# 11  1643155200     54.63   1017.00        4.61   287.86       292.62
# 12  1643241600     56.83   1016.67        4.34   287.38       291.80
# ...

# %% [markdown]
# ## Question 2

# %%
# !pip install psycopg2

# %%
import psycopg2


params_dic = {
    "host"      : "localhost",
    "database"  : "northwind",
    "user"      : "postgres",
    "password"  : "123"
}

conn = psycopg2.connect(**params_dic)
cursor = conn.cursor()

# %%
cursor.execute('select customers.company_name,customers.city, customers.country,count( orders.order_id ) as count from customers left join  orders on customers.customer_id = orders.customer_id group by customers.customer_id ')

# %%
df = pd.DataFrame(cursor.fetchall(), columns=['company_name','city','country','count'])
df
# Out:
#                          company_name          city      country  count
# 0                  Toms Spezialitäten       Münster      Germany      6
# 1            Lonesome Pine Restaurant      Portland          USA      8
# 2              Old World Delicatessen     Anchorage          USA     10
# 3                      Wartian Herkku          Oulu      Finland     15
# 4        Magazzini Alimentari Riuniti       Bergamo        Italy     10
# ..                                ...           ...          ...    ...
# 86                  LILA-Supermercado  Barquisimeto    Venezuela     14
# 87               White Clover Markets       Seattle          USA     14
# 88                 Richter Supermarkt        Genève  Switzerland     10
# 89  Trail's Head Gourmet Provisioners      Kirkland          USA      3
# 90              Bottom-Dollar Markets     Tsawassen       Canada     14
#
# [91 rows x 4 columns]

# %%
rslt_df = df.loc[df['count'] == 0]
rslt_df
# Out:
#                             company_name    city country  count
# 63  FISSA Fabrica Inter. Salchichas S.A.  Madrid   Spain      0
# 81                     Paris spécialités   Paris  France      0

# %%
cursor.close()

# %% [markdown]
# ## Question 3

# %%
html_tables = pd.read_html('https://www.premierleague.com/stats/top/players/goals?se=-1')
type(html_tables)
# Out:
# list

# %%
len(html_tables)
# Out:
# 1

# %%
players_df = html_tables[0]
players_df.head()
# Out:
#    Rank         Player Club Nationality  Stat  Unnamed: 5
# 0     1   Alan Shearer    -     England   260         NaN
# 1     2   Wayne Rooney    -     England   208         NaN
# 2     3    Andrew Cole    -     England   187         NaN
# 3     4  Sergio Agüero    -   Argentina   184         NaN
# 4     5  Frank Lampard    -     England   177         NaN

# %%
del players_df['Unnamed: 5']
players_df
# Out:
#     Rank                   Player               Club        Nationality  Stat
# 0      1             Alan Shearer                  -            England   260
# 1      2             Wayne Rooney                  -            England   208
# 2      3              Andrew Cole                  -            England   187
# 3      4            Sergio Agüero                  -          Argentina   184
# 4      5            Frank Lampard                  -            England   177
# 5      6            Thierry Henry                  -             France   175
# 6      7               Harry Kane  Tottenham Hotspur            England   170
# 7      8            Robbie Fowler                  -            England   163
# 8      9            Jermain Defoe                  -            England   162
# 9     10             Michael Owen                  -            England   150
# 10    11            Les Ferdinand                  -            England   149
# ...

# %% [markdown]
# ## Question 4

# %%
# !pip install --upgrade pandas --user

# %%
menu_df = pd.read_xml('../datasets/breakfast_menu.xml')
menu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         5 non-null      object
#  1   price        5 non-null      object
#  2   description  5 non-null      object
#  3   calories     5 non-null      int64
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes

# %%
menu_df.head()
# Out:
#                           name  price  \
# 0              Belgian Waffles  $5.95
# 1   Strawberry Belgian Waffles  $7.95
# 2  Berry-Berry Belgian Waffles  $8.95
# 3                 French Toast  $4.50
# 4          Homestyle Breakfast  $6.95
#
#                                          description  calories
# 0  Two of our famous Belgian Waffles with plenty ...       650
# 1  Light Belgian waffles covered with strawberrie...       900
# 2  Belgian waffles covered with assorted fresh be...       900
# 3  Thick slices made from our homemade sourdough ...       600
# 4  Two eggs, bacon or sausage, toast, and our eve...       950

# %%
del menu_df['description']
menu_df
# Out:
#                           name  price  calories
# 0              Belgian Waffles  $5.95       650
# 1   Strawberry Belgian Waffles  $7.95       900
# 2  Berry-Berry Belgian Waffles  $8.95       900
# 3                 French Toast  $4.50       600
# 4          Homestyle Breakfast  $6.95       950

# %%
menu_df['price'] = menu_df['price'].replace({'\$':''}, regex = True)
menu_df
# Out:
#                           name price  calories
# 0              Belgian Waffles  5.95       650
# 1   Strawberry Belgian Waffles  7.95       900
# 2  Berry-Berry Belgian Waffles  8.95       900
# 3                 French Toast  4.50       600
# 4          Homestyle Breakfast  6.95       950

# %% [markdown]
# ## Question 5

# %%
iris_df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_df.iloc[:,:-1].mean()
# Out:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
iris_df.iloc[:,:-1].max()
# Out:
# sepal_length    7.9
# sepal_width     4.4
# petal_length    6.9
# petal_width     2.5
# dtype: float64

# %%
iris_df.iloc[:,:-1].min()
# Out:
# sepal_length    4.3
# sepal_width     2.0
# petal_length    1.0
# petal_width     0.1
# dtype: float64
